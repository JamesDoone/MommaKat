# %%
import pandas as pd

# %%
# %cd Desktop/
# Out:
# /Users/jimdoone/Desktop

# %%
# %ls
# Out:
# Activation_Function.png
# Desktop/
# Desktop_Data/
# Icon?
# JamesDoone_cv.docx
# Jobs/
# PVPMC/
# Python/
# SCREEN_SHOTS/
# Step_by_step_gradient_descent.png
# choosing_colors.pdf
# jamesbond.csv
# kc_house_data.csv*
# machine/
# pandas_data_files/
# references.docx
# test.csv
# train.csv
# ~$E POSITION .docx
# ~$EDExercise 1 Simple Project Finance Model.xlsm
# ~$Excel2013StatisticsChapter07.xlsm
# ~$Fred_2013.xlam
# ~$HCA.xlsx
# ~$P90, P99 etc Analysis.xlsx
# ~$Python.docx
# ~$Read PDF to Excel.xlsm
# ~$Risk_2.xlsx
# ~$Solar Model Version 3.xlsm
# ~$anddo_Excel_notes.docx
# ~$ats_notes.docx
# ~$ergy Primer.docx
# ~$mes_Doone_Alcen_CL.docx
# ~$mes_Doone_Tesla.docx
# ~$n_Leffern__Mark_20150227 (1).docx
# ~$oone_CSE_CL.docx
# ~$oone_Duq.docx
# ~$rect Current Transmission Lines.docx

# %%
james = pd.read_csv('jamesbond.csv', index_col='Film')
james.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %% [markdown]
# ##### default = rows (either a string for name of index or number)
# ##### To drop a column, must change 'axis=1' or axis = "columns"
# ##### Must include inplace = True

# %%
james.drop(['Dr. No', 'Goldfinger'], inplace=True)

# %%
james
# Out:
#                                  Year           Actor            Director  \
# Film
# From Russia with Love            1963    Sean Connery       Terence Young
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# For Your Eyes Only               1981     Roger Moore           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# ...

# %% [markdown]
# ##### Drop Columns

# %%
james.drop('Budget', axis = 'columns', inplace=True)

# %%
james
# Out:
#                                  Year           Actor            Director  \
# Film
# From Russia with Love            1963    Sean Connery       Terence Young
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# For Your Eyes Only               1981     Roger Moore           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# ...
