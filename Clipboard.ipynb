# %%
import pandas as pd
import numpy as np

# %%
import webbrowser
url = "https://www.eia.gov/environment/emissions/state/analysis/pdf/table1.pdf"
webbrowser.open(url)
# Out:
# True

# %%
emission = pd.read_clipboard()

# %%
emission
# Out:
#          State   2000   2001   2002   2003   2004   2005   2006   2007   2008  \
# 0      Alabama  142.2  133.6  138.4  139.3  141.6  143.3  145.7  147.4  139.6
# 1       Alaska   44.3   43.4   43.6   43.6   46.8   48.1   45.8   44.0   39.4
# 2      Arizona   86.1   88.4   87.8   89.6   96.6   96.7   99.9  101.9  102.3
# 3     Arkansas   63.7   62.9   61.4   62.1   62.4   60.2   62.1   63.4   64.2
# 4   California  382.4  386.8  386.0  373.8  392.2  389.4  397.6  402.6  385.8
# 5     Colorado   84.6   92.7   90.8   90.2   93.2   95.4   96.4   99.0   97.0
# 6  Connecticut   43.0   41.7   40.1   42.8   44.6   44.1   41.0   40.3   37.7
# 7     Delaware   16.7   16.1   15.9   16.5   16.6   17.4   16.2   17.1   16.2
#
#     2009   2010   2011   2012   2013   2014 percent  absolute
# 0  120.0  132.7  129.9  123.2  120.9  123.2  -13.4%     -19.0
# 1   37.8   38.7   38.5   38.0   36.3   35.1  -20.9%      -9.3
# 2   93.4   95.3   93.3   91.3   95.1   93.1    8.2%       7.1
# ...
