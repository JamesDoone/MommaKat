# %%
import pandas as pd

# %%
# %cd pandas_data_files/
# Out:
# /Users/jimdoone/Desktop/pandas_data_files

# %%
bf = pd.read_csv('bigmac.csv', index_col=['Date', 'Country'], parse_dates=['Date'])
bf.sort_index(inplace=True)
bf.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bf.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %%
for i in bf.index.get_level_values(0):
    print(i)
    #for j in bf.index.get_level_values(1):
        #df = bf.loc[(i, j), :]
# Out:
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-01-01 00:00:00
# 2010-07-01 00:00:00
# 2010-07-01 00:00:00
# ...

# %%
bf.loc[("2010-01-01", "Brazil") : ("2010-01-01", "Turkey")]
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71
#            Denmark                        5.99
#            Egypt                          2.38
#            Euro area                      4.84
#            Hong Kong                      1.91
#            Hungary                        3.86
#            Indonesia                      2.24
#            Israel                         3.99
#            Japan                          3.50
#            Latvia                         3.09
#            Lithuania                      2.87
# ...
