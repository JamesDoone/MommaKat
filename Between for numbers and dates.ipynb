# %%
import pandas as pd

# %%
# %cd pandas_data_files/
# Out:
# /Users/jimdoone/Desktop/pandas_data_files

# %%
df = pd.read_csv('employees.csv')
df.head(2)
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas   Male  3/31/1996         6:53 AM   61933    4.170
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN

# %%
mask = df['Salary'].between(90_000, 100_000)
df[mask]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 16      Jeremy    Male   9/21/2010         5:56 AM   90370    7.369
# 22      Joshua     NaN    3/8/2012         1:58 AM   90816   18.816
# 24        John    Male    7/1/1992        10:08 PM   97950   13.873
# 34       Jerry    Male   1/10/2004        12:56 PM   95734   19.096
# 40     Michael    Male  10/10/2008        11:25 AM   99283    2.665
# 48    Clarence    Male   3/26/1996         5:57 AM   93581    6.083
# 50       Nancy  Female   9/23/2000         8:05 AM   94976   13.830
# 73     Frances  Female    4/4/1999         4:19 PM   90582    4.709
# 90      Janice     NaN   8/21/1997         5:12 AM   91719   11.583
# 105      Kathy  Female    3/9/1996         4:33 AM   91712    8.567
# 131    Rebecca  Female   7/10/1992        12:23 AM   94231   17.517
# ...

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])

# %% [markdown]
# ##### First argument is the lower bound, 2nd is the upper bound

# %%
df[df['Start Date'].between('1991-01-01', '1992-01-01')]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11         6:58 PM  122367    5.218
# 75      Bonnie  Female 1991-07-02         1:27 AM  104897    5.118
# 88       Donna  Female 1991-11-27         1:59 PM   64088    6.155
# 116        NaN    Male 1991-06-22         8:58 PM   76189   18.988
# 148    Patrick     NaN 1991-07-14         2:24 AM  124488   14.837
# 166        NaN  Female 1991-07-09         6:52 PM   42341    7.014
# 172       Sara  Female 1991-09-23         6:17 PM   97058    9.402
# 220        NaN  Female 1991-06-17        12:49 PM   71945    5.560
# 245     Victor    Male 1991-04-11         7:44 AM   70817   17.138
# 277     Brenda     NaN 1991-05-29         6:32 AM   82439   19.062
# 313       Judy  Female 1991-07-01         2:33 AM  109510   13.457
# 328     Samuel    Male 1991-12-19         2:54 AM   76076    5.319
# 339    Michael    Male 1991-11-22        12:57 PM   98753   16.443
# ...
